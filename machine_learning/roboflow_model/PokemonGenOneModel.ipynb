# %%
import roboflow
from ultralytics import YOLO
import os

HOME = os.getcwd()
print(HOME)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/harning/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# /home/harning/School/Python/ml_python_exam_project/machine_learning/roboflow_model

# %%
# logs the user in to roboflow and downloads the project to the current folder

# roboflow.login()
# rf = roboflow.Roboflow()
# project = rf.workspace('sofuss-workspace').project('pokemon-piesw-y4s7z')
# version = project.version(1)
# dataset = version.download('folder')

# print(dataset.location)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# /home/harning/School/Python/ml_python_exam_project/machine_learning/roboflow_model/Pokemon-1

# %%
model = YOLO('yolov8n-cls.pt')

# %%
save_dir = './machine_learning/roboflow_model/Pokemon-1/train'
os.makedirs(save_dir, exist_ok=True)

model.train(
    data='./Pokemon-1',
    epochs=1,
    imgsz=224,
    device='cpu',
    batch=16,
    patience=15,
    project=f'{HOME}',
    save_dir=save_dir
)
# Out:
# Ultralytics 8.4.46 🚀 Python-3.14.4 torch-2.11.0+cu130 CPU (Intel Core Ultra 7 155H)
# ...

# %%
model.predict(
    source='./Pokemon-1/test/Psyduck',
    imgsz=1280,
    device='cpu'
)
# Out:
# image 1/38 /home/harning/School/Python/ml_python_exam_project/machine_learning/roboflow_model/Pokemon-1/test/Psyduck/00000002_png.rf.fdbaaa2b7d3cb20e96d0637f64b3b911.jpg: 1280x1280 Kabuto 0.02, Shellder 0.01, Psyduck 0.01, Snorlax 0.01, Vileplume 0.01, 170.8ms
# image 2/38 /home/harning/School/Python/ml_python_exam_project/machine_learning/roboflow_model/Pokemon-1/test/Psyduck/00000005_jpg.rf.00746baa584db3bde784539bb5029bfc.jpg: 1280x1280 Kabuto 0.02, Shellder 0.01, Snorlax 0.01, Rattata 0.01, Charizard 0.01, 137.1ms
# image 3/38 /home/harning/School/Python/ml_python_exam_project/machine_learning/roboflow_model/Pokemon-1/test/Psyduck/00000007_png.rf.03c21a88be5648d3c491e0903049877e.jpg: 1280x1280 Shellder 0.01, Kabuto 0.01, Rattata 0.01, Psyduck 0.01, Charizard 0.01, 110.7ms
# ...

# %%
model.val(
    data='./Pokemon-1',
    device='cpu'
)
# Out:
# Ultralytics 8.4.46 🚀 Python-3.14.4 torch-2.11.0+cu130 CPU (Intel Core Ultra 7 155H)
# YOLOv8n-cls summary (fused): 30 layers, 1,627,030 parameters, 0 gradients, 3.4 GFLOPs
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /home/harning/School/Python/ml_python_exam_project/machine_learning/roboflow_model/Pokemon-1/train... found 19092 images in 150 classes ✅
# val: /home/harning/School/Python/ml_python_exam_project/machine_learning/roboflow_model/Pokemon-1/test... found 3400 images in 150 classes ✅
# test: /home/harning/School/Python/ml_python_exam_project/machine_learning/roboflow_model/Pokemon-1/test... found 3400 images in 150 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1880.0±1173.5 MB/s, size: 50.9 KB)
# val: Scanning /home/harning/School/Python/ml_python_exam_project/machine_learning/roboflow_model/Pokemon-1/test... 3400 images, 0 corrupt: 100% ━━━━━━━━━━━━ 3400/3400 594.2Mit/s 0.0s
# ...
